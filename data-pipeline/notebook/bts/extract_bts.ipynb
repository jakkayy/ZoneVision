# %%
import pandas as pd
import json
import requests
import time

# %%
url = "https://drt.gdcatalog.go.th/en/api/3/action/datastore_search"
resource_id = "8a8d53fc-0c9c-4301-a354-8529bf487ceb"

all_records = []
limit = 10000
offset = 0

# %%
while True:
    params = {"resource_id": resource_id, "limit": limit, "offset": offset}

    print(f"กำลังดึงข้อมูล แถวที่ {offset} ถึง {offset + limit}...")
    response = requests.get(url, params=params)

    if response.status_code == 200:
        result = response.json()["result"]
        records = result["records"]

        if not records:
            break

        all_records.extend(records)

        offset += limit

        time.sleep(1)
    else:
        print(f"เกิดข้อผิดพลาด: {response.status_code}")
        break

print(f"🎉 ดึงข้อมูลเสร็จสิ้น! ได้ข้อมูลทั้งหมด {len(all_records)} แถว")
# Out:
# กำลังดึงข้อมูล แถวที่ 0 ถึง 10000...
# กำลังดึงข้อมูล แถวที่ 10000 ถึง 20000...
# กำลังดึงข้อมูล แถวที่ 20000 ถึง 30000...
# 🎉 ดึงข้อมูลเสร็จสิ้น! ได้ข้อมูลทั้งหมด 11660 แถว

# %%
print(all_records[:5])
# Out:
# [{'_id': 1, 'No.': 1, 'Date': '1/10/2022', 'Organization': 'SRT', 'Number_Passenger': '52,584', 'Note': None}, {'_id': 2, 'No.': 2, 'Date': '1/10/2022', 'Organization': 'ARL', 'Number_Passenger': '46,393', 'Note': None}, {'_id': 3, 'No.': 3, 'Date': '1/10/2022', 'Organization': 'Red Line', 'Number_Passenger': '12,558', 'Note': None}, {'_id': 4, 'No.': 4, 'Date': '1/10/2022', 'Organization': 'MRT Blue Line', 'Number_Passenger': '221,452', 'Note': None}, {'_id': 5, 'No.': 5, 'Date': '1/10/2022', 'Organization': 'MRT Purple Line', 'Number_Passenger': '24,843', 'Note': None}]

# %%
df = pd.DataFrame(all_records)
df
# Out:
#          _id    No.       Date     Organization Number_Passenger Note
# 0          1      1  1/10/2022              SRT           52,584  NaN
# 1          2      2  1/10/2022              ARL           46,393  NaN
# 2          3      3  1/10/2022         Red Line           12,558  NaN
# 3          4      4  1/10/2022    MRT Blue Line          221,452  NaN
# 4          5      5  1/10/2022  MRT Purple Line           24,843  NaN
# ...      ...    ...        ...              ...              ...  ...
# 11655  11656  11656    30/6/26  MRT Purple Line            81654  NaN
# 11656  11657  11657    30/6/26  MRT Yellow Line            54735  NaN
# 11657  11658  11658    30/6/26    MRT Pink Line            80121  NaN
# 11658  11659  11659    30/6/26   BTS Green Line           762811  NaN
# 11659  11660  11660    30/6/26    BTS Gold Line             6984  NaN
#
# [11660 rows x 6 columns]

# %%
df.to_csv("../../data/raw/bts.csv", index=False)
